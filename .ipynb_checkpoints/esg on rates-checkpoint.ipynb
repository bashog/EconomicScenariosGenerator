# %% [markdown]
# # Importation of librairies and data

# %%
# reload
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
import random
import sys
sys.path.append('./')

from timeseries import TimeSeries
# Out:
# Generate data done

# %%
dftaux = pd.read_csv(filepath_or_buffer = './datas/exchange_rates_ecb_eur_updated_2023.csv',sep = '\t')
dftaux.head()
# Out:
#          Date     USD     JPY  BGN     CZK     DKK      GBP     HUF     PLN  \
# 0  1999-01-04  1.1789  133.73  NaN  35.107  7.4501  0.71110  251.48  4.0712
# 1  1999-01-05  1.1790  130.96  NaN  34.917  7.4495  0.71220  250.80  4.0245
# 2  1999-01-06  1.1743  131.42  NaN  34.850  7.4452  0.70760  250.67  4.0065
# 3  1999-01-07  1.1632  129.43  NaN  34.886  7.4431  0.70585  250.09  4.0165
# 4  1999-01-08  1.1659  130.09  NaN  34.938  7.4433  0.70940  250.15  4.0363
#
#    RON  ...  ILS  INR      KRW  MXN  MYR     NZD  PHP     SGD  THB     ZAR
# 0  NaN  ...  NaN  NaN  1398.59  NaN  NaN  2.2229  NaN  1.9554  NaN  6.9358
# 1  NaN  ...  NaN  NaN  1373.01  NaN  NaN  2.2011  NaN  1.9655  NaN  6.7975
# 2  NaN  ...  NaN  NaN  1359.54  NaN  NaN  2.1890  NaN  1.9699  NaN  6.7307
# 3  NaN  ...  NaN  NaN  1337.16  NaN  NaN  2.1531  NaN  1.9436  NaN  6.8283
# 4  NaN  ...  NaN  NaN  1366.73  NaN  NaN  2.1557  NaN  1.9537  NaN  6.7855
#
# [5 rows x 33 columns]

# %% [markdown]
# # Initialisation of the multi timeseries

# %%
symbols = ['USD', 'JPY', 'GBP', 'CAD']

# %%
random.seed(14021999)
ts = TimeSeries(dftaux, symbols)
ts.pre_processing(method_return='arithmetic')

# %%
ts.plot(type_plot='rates')

# %% [markdown]
# # Analysis of the timeseries

# %%
ts.plot(type_plot='rates')

# %%
ts.plot(type_plot='returns', frequency = 'weekly')

# %%
ts.statistics()
# Out:
#                    USD       JPY       GBP       CAD
# Skewness     -0.002371 -0.122293  0.094618  0.059594
# Kurtosis      3.166775  3.557793  3.279398  3.257275
# Normality         True     False     False     False
# Stationarity      True      True      True      True

# %%
ts.correlation()

# %% [markdown]
# ## Bootstrap method

# %%
test_dates = '2021-09-04'
plot_from='2020-01-01'
scenarios = 100
frequency = 'annualy'
ts.bootstrap_esg(scenarios=scenarios, test_date=test_dates, plot_from=plot_from, frequency=frequency)
# Out:
# Correlation done
# Quantiles done
#          Bootstrap
# train     0.014174
# generate   0.03296

# %% [markdown]
# ## RBM method

# %%
test_dates = '2021-09-04'
plot_from='2020-01-01'
scenarios = 10
epochs = 5000
lr = 0.015
windows = 5
K = 100
frequency = 'weekly'
numba = True
ts.rbm_esg(scenarios, epochs, lr, K, numba, test_dates, plot_from, windows, frequency=frequency)
# Out:
#   0%|          | 5/5000 [00:00<01:42, 48.63it/s]
# Pre-processing done
# 100%|██████████| 5000/5000 [00:37<00:00, 132.35it/s]
# Correlation done
# Train done
# Time to generate the data: 322.59767293930054s
# Correlation done
# Quantiles done
#                  RBM
# train       37.77756
# generate  322.597673

# %%
ts.performance()
# Out:
#          Bootstrap         RBM
# train     0.014174    37.77756
# generate   0.03296  322.597673

# %%
import random
import numba
import numpy as np

def monte_carlo_pi(n_samples):
    acc = 0
    for i in range(n_samples):
        x = random.random()
        y = random.random()
        if x**2 + y**2 <= 1:
            acc += 1
    return 4*acc/n_samples

def sigmoid(x):
    return 1/(1+np.exp(-x))

@numba.njit
def monte_carlo_pi_numba(n_samples):
    acc = 0
    for i in range(n_samples):
        x = random.random()
        y = random.random()
        if x**2 + y**2 <= 1:
            acc += 1
    return 4*acc/n_samples

# %%
monte_carlo_pi(10000000)
# Out:
# 3.1419032

# %%
# %timeit monte_carlo_pi_numba(10000000)
# Out:
# 72.5 ms ± 946 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
